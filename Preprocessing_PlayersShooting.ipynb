# %%
import os
import numpy as np
import pandas as pd

# %%
path = os.path.join('Data','Raw')
nome_file = 'Player Shooting.csv'

df = pd.read_csv( os.path.join( path, nome_file ) )
file_teams = 'Team Abbrev.csv'
teams_abb = pd.read_csv( os.path.join(path, file_teams))
#Visualizzo i nomi delle colonne per facilitare i passi successivi
df.columns
# Out:
# Index(['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age',
#        'experience', 'lg', 'tm', 'g', 'mp', 'fg_percent', 'avg_dist_fga',
#        'percent_fga_from_x2p_range', 'percent_fga_from_x0_3_range',
#        'percent_fga_from_x3_10_range', 'percent_fga_from_x10_16_range',
#        'percent_fga_from_x16_3p_range', 'percent_fga_from_x3p_range',
#        'fg_percent_from_x2p_range', 'fg_percent_from_x0_3_range',
#        'fg_percent_from_x3_10_range', 'fg_percent_from_x10_16_range',
#        'fg_percent_from_x16_3p_range', 'fg_percent_from_x3p_range',
#        'percent_assisted_x2p_fg', 'percent_assisted_x3p_fg',
#        'percent_dunks_of_fga', 'num_of_dunks', 'percent_corner_3s_of_3pa',
#        'corner_3_point_percent', 'num_heaves_attempted', 'num_heaves_made'],
#       dtype='object')

# %%
df
# Out:
#        seas_id  season  player_id                player  birth_year pos  age  \
# 0        31136    2024       5025            A.J. Green         NaN  SG   24
# 1        31137    2024       5026           A.J. Lawson         NaN  SG   23
# 2        31138    2024       5027            AJ Griffin         NaN  SF   20
# 3        31139    2024       4219          Aaron Gordon         NaN  PF   28
# 4        31140    2024       4582         Aaron Holiday         NaN  PG   27
# ...        ...     ...        ...                   ...         ...  ..  ...
# 16780    15656    1997       2632         Willie Burton         NaN  SF   28
# 16781    15657    1997       2278       Xavier McDaniel         NaN  PF   33
# 16782    15658    1997       2890            Yinka Dare         NaN   C   24
# 16783    15567    1997       2540  Šarūnas Marčiulionis         NaN  SG   32
# 16784    15659    1997       2891             Žan Tabak         NaN   C   26
#
# ...

# %%
df = df[df['season']>2003]
df = df.drop(columns=['birth_year', 'pos', 'age',
       'experience', 'lg', 'tm',])

# %%
df.fillna(0)
# Out:
#        seas_id  season  player_id              player   g    mp  fg_percent  \
# 0        31136    2024       5025          A.J. Green  56   614       0.423
# 1        31137    2024       5026         A.J. Lawson  42   311       0.446
# 2        31138    2024       5027          AJ Griffin  20   171       0.290
# 3        31139    2024       4219        Aaron Gordon  73  2297       0.556
# 4        31140    2024       4582       Aaron Holiday  78  1269       0.446
# ...        ...     ...        ...                 ...  ..   ...         ...
# 13136    19314    2004       3100  Zydrunas Ilgauskas  81  2539       0.483
# 13137    19307    2004       3493     Žarko Čabarkapa  49   570       0.411
# 13138    19309    2004       3364      Željko Rebrača  24   273       0.442
# 13139    19310    2004       3364      Željko Rebrača  21   222       0.407
# 13140    19311    2004       3364      Željko Rebrača   3    51       0.522
#
# ...

# %%
df.to_parquet( os.path.join( 'Data', 'Parquet', 'assistedstats.parquet') )
